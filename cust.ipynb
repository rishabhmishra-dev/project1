# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df=pd.read_csv('cust_satisfaction.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  str
#  1   Customer Type               103904 non-null  str
#  2   Type of Travel              103904 non-null  str
#  3   Class                       103904 non-null  str
#  4   satisfaction                103904 non-null  str
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 9.5 MB

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
df[['Customer Type']]
# Out:
#             Customer Type
# 0          Loyal Customer
# 1       disloyal Customer
# 2          Loyal Customer
# 3          Loyal Customer
# 4          Loyal Customer
# ...                   ...
# 103899  disloyal Customer
# 103900     Loyal Customer
# 103901  disloyal Customer
# 103902  disloyal Customer
# 103903     Loyal Customer
#
# [103904 rows x 1 columns]

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# ...

# %%
df.tail()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction    Age  \
# 0        False          False           False  False         False  False
# 1        False          False           False  False         False  False
# 2        False          False           False  False         False  False
# 3        False          False           False  False         False  False
# 4        False          False           False  False         False  False
# ...        ...            ...             ...    ...           ...    ...
# 103899   False          False           False  False         False  False
# 103900   False          False           False  False         False  False
# 103901   False          False           False  False         False  False
# 103902   False          False           False  False         False  False
# 103903   False          False           False  False         False  False
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.dropna()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df['Type of Travel'].unique()
# Out:
# <StringArray>
# ['Personal Travel', 'Business travel']
# Length: 2, dtype: str

# %%
df['Type of Travel'].nunique()
# Out:
# 2

# %%
df['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    71331
# Personal Travel    32091
# Name: count, dtype: int64

# %%
char =df.select_dtypes(include='object')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_828\2101896211.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   char =df.select_dtypes(include='object')

# %%
iint=df.select_dtypes(exclude='object')

# %%
char
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
# ...                         ...
# ...

# %%
iint
# Out:
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 0        13              460                       5                 4
# 1        25              235                       1                 3
# 2        26             1142                       5                 4
# 3        25              562                       2                 3
# 4        61              214                       3                 4
# ...     ...              ...                     ...               ...
# 103899   23              192                       2                 4
# 103900   49             2347                       5                 5
# 103901   30             1995                       4                 4
# 103902   22             1000                       1                 1
# 103903   27             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103422 non-null  str
#  1   Customer Type               103422 non-null  str
#  2   Type of Travel              103422 non-null  str
#  3   Class                       103422 non-null  str
#  4   satisfaction                103422 non-null  str
#  5   Age                         103422 non-null  int64
#  6   Flight Distance             103422 non-null  int64
#  7   Inflight entertainment      103422 non-null  int64
#  8   Baggage handling            103422 non-null  int64
#  9   Cleanliness                 103422 non-null  int64
#  10  Departure Delay in Minutes  103422 non-null  int64
#  11  Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 10.3 MB

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.drop(['Type of Travel','Class'],axis=1,inplace=True)

# %%
df['Customer Type'].unique()
# Out:
# <StringArray>
# ['Loyal Customer', 'disloyal Customer']
# Length: 2, dtype: str

# %%
df[df['Customer Type']=='Loyal Customer']
# Out:
#         Gender   Customer Type             satisfaction  Age  Flight Distance  \
# 0         Male  Loyal Customer  neutral or dissatisfied   13              460
# 2       Female  Loyal Customer                satisfied   26             1142
# 3       Female  Loyal Customer  neutral or dissatisfied   25              562
# 4         Male  Loyal Customer                satisfied   61              214
# 5       Female  Loyal Customer  neutral or dissatisfied   26             1180
# ...        ...             ...                      ...  ...              ...
# 103896    Male  Loyal Customer  neutral or dissatisfied   57              867
# 103897  Female  Loyal Customer                satisfied   60             1599
# 103898    Male  Loyal Customer  neutral or dissatisfied   50             1620
# 103900    Male  Loyal Customer                satisfied   49             2347
# 103903    Male  Loyal Customer  neutral or dissatisfied   27             1723
#
# ...

# %%
CustType_dict={
    'Loyal Customer':1, 'disloyal Customer':0
}
df['Customer Type']=df['Customer Type'].map(CustType_dict)

# %%
df
# Out:
#         Gender  Customer Type             satisfaction  Age  Flight Distance  \
# 0         Male              1  neutral or dissatisfied   13              460
# 1         Male              0  neutral or dissatisfied   25              235
# 2       Female              1                satisfied   26             1142
# 3       Female              1  neutral or dissatisfied   25              562
# 4         Male              1                satisfied   61              214
# ...        ...            ...                      ...  ...              ...
# 103899  Female              0  neutral or dissatisfied   23              192
# 103900    Male              1                satisfied   49             2347
# 103901    Male              0  neutral or dissatisfied   30             1995
# 103902  Female              0  neutral or dissatisfied   22             1000
# 103903    Male              1  neutral or dissatisfied   27             1723
#
# ...

# %%
df['satisfaction'].unique()
# Out:
# <StringArray>
# ['neutral or dissatisfied', 'satisfied']
# Length: 2, dtype: str

# %%
satis_dict={
    'neutral or dissatisfied':0, 'satisfied':1
}
df['satisfaction']=df['satisfaction'].map(satis_dict)

# %%
df
# Out:
#         Gender  Customer Type  satisfaction  Age  Flight Distance  \
# 0         Male              1             0   13              460
# 1         Male              0             0   25              235
# 2       Female              1             1   26             1142
# 3       Female              1             0   25              562
# 4         Male              1             1   61              214
# ...        ...            ...           ...  ...              ...
# 103899  Female              0             0   23              192
# 103900    Male              1             1   49             2347
# 103901    Male              0             0   30             1995
# 103902  Female              0             0   22             1000
# 103903    Male              1             0   27             1723
#
#         Inflight entertainment  Baggage handling  Cleanliness  \
# 0                            5                 4            5
# ...

# %%
df.drop("Gender",axis=1,inplace=True)

# %%
df
# Out:
#         Customer Type  satisfaction  Age  Flight Distance  \
# 0                   1             0   13              460
# 1                   0             0   25              235
# 2                   1             1   26             1142
# 3                   1             0   25              562
# 4                   1             1   61              214
# ...               ...           ...  ...              ...
# 103899              0             0   23              192
# 103900              1             1   49             2347
# 103901              0             0   30             1995
# 103902              0             0   22             1000
# 103903              1             0   27             1723
#
#         Inflight entertainment  Baggage handling  Cleanliness  \
# 0                            5                 4            5
# 1                            1                 3            1
# 2                            5                 4            5
# ...

# %%
x=df.drop('Flight Distance',axis=1)

# %%
x
# Out:
#         Customer Type  satisfaction  Age  Inflight entertainment  \
# 0                   1             0   13                       5
# 1                   0             0   25                       1
# 2                   1             1   26                       5
# 3                   1             0   25                       2
# 4                   1             1   61                       3
# ...               ...           ...  ...                     ...
# 103899              0             0   23                       2
# 103900              1             1   49                       5
# 103901              0             0   30                       4
# 103902              0             0   22                       1
# 103903              1             0   27                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# ...

# %%
y=df[['Flight Distance']]

# %%
y
# Out:
#         Flight Distance
# 0                   460
# 1                   235
# 2                  1142
# 3                   562
# 4                   214
# ...                 ...
# 103899              192
# 103900             2347
# 103901             1995
# 103902             1000
# 103903             1723
#
# [103422 rows x 1 columns]

# %%
! pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn as sns

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train ,y_test =train_test_split(x , y , test_size=0.2, random_state= 42)

# %%
print(x_train.shape, x_test.shape , y_train.shape ,y_test.shape)
# Out:
# (82737, 8) (20685, 8) (82737, 1) (20685, 1)

# %%
x_train
# Out:
#        Customer Type  satisfaction  Age  Inflight entertainment  \
# 71834              0             0   50                       5
# 76517              1             0   21                       1
# 29502              1             1   48                       5
# 7185               1             0   56                       2
# 31081              1             1   52                       5
# ...              ...           ...  ...                     ...
# 6284               1             0   27                       4
# 55092              1             0   23                       4
# 77137              0             0   39                       4
# 861                1             1   24                       3
# 15837              1             0   53                       4
#
#        Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 71834                 4            5                          24
# ...

# %%
y_train
# Out:
#        Flight Distance
# 71834              179
# 76517             1120
# 29502             3403
# 7185              1721
# 31081              933
# ...                ...
# 6284              1671
# 55092              255
# 77137              761
# 861               1013
# 15837              305
#
# [82737 rows x 1 columns]

# %%
x_test
# Out:
#        Customer Type  satisfaction  Age  Inflight entertainment  \
# 40794              1             1   38                       4
# 28574              1             1   50                       5
# 4920               1             0   72                       1
# 71169              1             1   45                       5
# 67168              1             1   39                       5
# ...              ...           ...  ...                     ...
# 78398              0             1   22                       5
# 47803              1             1   47                       5
# 69942              1             0   25                       1
# 6464               1             0   24                       4
# 49721              1             0   56                       2
#
#        Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 40794                 4            1                           0
# ...

# %%
y_test
# Out:
#        Flight Distance
# 40794             2623
# 28574             1617
# 4920               270
# 71169             1998
# 67168             2153
# ...                ...
# 78398              937
# 47803              956
# 69942             1576
# 6464               622
# 49721              821
#
# [20685 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#        Customer Type  satisfaction  Age  Inflight entertainment  \
# 40794              1             1   38                       4
# 28574              1             1   50                       5
# 4920               1             0   72                       1
# 71169              1             1   45                       5
# 67168              1             1   39                       5
# ...              ...           ...  ...                     ...
# 78398              0             1   22                       5
# 47803              1             1   47                       5
# 69942              1             0   25                       1
# 6464               1             0   24                       4
# 49721              1             0   56                       2
#
#        Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 40794                 4            1                           0
# ...

# %%
pred =lr.predict(x_test)

# %%
lst=[[1	,1,	38,	4,	4,	1,	0,	0.0]]

# %%
lr.predict(lst)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1585.11917344]])

# %%
pred
# Out:
# array([[1585.11917344],
#        [1578.34730756],
#        [1071.33372894],
#        ...,
#        [1020.07393015],
#        [1016.17244953],
#        [1053.57809446]], shape=(20685, 1))

# %%
y_test
# Out:
#        Flight Distance
# 40794             2623
# 28574             1617
# 4920               270
# 71169             1998
# 67168             2153
# ...                ...
# 78398              937
# 47803              956
# 69942             1576
# 6464               622
# 49721              821
#
# [20685 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
rfg =RandomForestRegressor()

# %%
rfg.fit(x_train, y_train)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
lst=[[1	,1,	38,	4,	4,	1,	0,	0.0]]
rfg.predict(lst)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([1982.40865858])

# %%
lst=[[1	,1,	38,	4,	4,	1,	0,	0.0]]
rfg.predict(lst)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([1954.35906425])

# %%
x_test
# Out:
#        Customer Type  satisfaction  Age  Inflight entertainment  \
# 40794              1             1   38                       4
# 28574              1             1   50                       5
# 4920               1             0   72                       1
# 71169              1             1   45                       5
# 67168              1             1   39                       5
# ...              ...           ...  ...                     ...
# 78398              0             1   22                       5
# 47803              1             1   47                       5
# 69942              1             0   25                       1
# 6464               1             0   24                       4
# 49721              1             0   56                       2
#
#        Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 40794                 4            1                           0
# ...

# %%
pred =rfg.predict(x_test)

# %%
pred
# Out:
# array([1982.40865858, 1771.01      ,  878.259     , ..., 1141.9194061 ,
#         722.50951398, 1093.94692713], shape=(20685,))

# %%
y_test
# Out:
#        Flight Distance
# 40794             2623
# 28574             1617
# 4920               270
# 71169             1998
# 67168             2153
# ...                ...
# 78398              937
# 47803              956
# 69942             1576
# 6464               622
# 49721              821
#
# [20685 rows x 1 columns]
